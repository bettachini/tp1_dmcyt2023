# %% [markdown]
# # TP 1: Data mining en imágenes

# %% [markdown]
# ![img.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# _Data mining en Ciencia y Tecnología_
# 2do cuatrimestre 2023

# %% [markdown]
# Integrantes del grupo:
# Zambrano, Vanesa; Pirola, Malena; Gianni, Tomás; Bettachini, Víctor

# %% [markdown]
# ## Enunciado

# %% [markdown]
# Transcribo el texto del enunciado como
# >  comentarios
#
# para ordenar lo que se vuelque aquí

# %% [markdown]
# ## 1. Introducción

# %% [markdown]
# > Dentro de la minería de datos encontramos el procesamiento de imágenes como un campo en constante evolución. Hoy en día, son muchas las aplicaciones que funcionan a partir de cámaras, sensores, equipamiento médico, o satélites. Estos sistemas permiten extraer una gran cantidad de información en formato de imagen, lo cual hace muy dificil la inspección humana de la misma. Poder extraer características y poder agrupar las imágenes en base de ellas es sumamente importante la utilización de algoritmos de aprendizaje automático.

# %% [markdown]
# ## 2. Objetivos

# %% [markdown]
# > Realizar un agrupamiento de un conjunto de imágenes. Comparar las segmentaciones genereadas por diferentes algoritmos de clustering en base a métodos de validación interna
# y externa.
#
# > En función del dataset elegido se podrá definir una pregunta específica, está puede estar guiada por una pregunta básica o por una aplicación. Les proponemos pensar esta preguntar e incluirla como guía del trabajo. Deberá estar motivada en la sección Introducción (idealmente con bibliografía) y discutida en la sección Discusión o Conclusiones

# %% [markdown]
# ## 3. Estructura de los datos

# %% [markdown]
# > Deberán elegir un dataset, donde haya al menos 5 categorias. Dejamos ejemplos de algunos sets de datos que pueden usar, pero pueden elegir otro que sea de su interés tomando estos como parámetro.
# > - **Imágenes naturales**: 6899 imágenes de 8 clases diferentes (aviones, autos, gatos, flores, perros, frutas, motos y personas): https://www.kaggle.com/datasets/prasunroy/
# natural-images [1].
# > - **Imágenes de tipos de arroz**: 5 clases de arroz diferentes (Arborio, Basmati, Ipsala, Jasmine, Karacadag, ): https://www.kaggle.com/datasets/muratkokludataset/rice-image-dat
# [2].
# > - **Ropa**: Varias categorías de prendas de vestir. Hay que hacer una subsampleo de la muestra porque es muy grande: https://www.kaggle.com/datasets/paramaggarwal/
# fashion-product-images-small
# > - **Galaxias**: Distintas categorias de galaxias anotadas por voluntarios (online). Dataset: https://astronn.readthedocs.io/en/latest/galaxy10.html, Plataforma para anotar: https://www.zooniverse.org/projects/zookeeper/galaxy-zoo/classify
# >
# > [1] Prasun Roy, Subhankar Ghosh, Saumik Bhattacharya, and Umapada Pal. Effects of degradations on deep neural network architectures. arXiv preprint arXiv:1807.10108, 2018.
# > [2] Ilkay Cinar and Murat Koklu. Classification of rice varieties using artificial intelligence methods. International Journal of Intelligent Systems and Applications in Engineering, 7(3):188–194, 2019.
# > [3] Karen Simonyan and Andrew Zisserman. Very deep convolutional networks for large-scale image recognition. arXiv preprint arXiv:1409.1556, 2014.
# > [4] Seán I O’Donoghue, Benedetta Frida Baldi, Susan J Clark, Aaron E Darling, James M Hogan, Sandeep Kaur, Lena Maier-Hein, Davis J McCarthy, William J Moore, Esther Stenau, et al Visualization of biomedical data. Annual Review of Biomedical Data Science, 1(1):275–304, 2018.
#
#
# Se trabaja a continuación sobre el conjunto de **Imágenes de tipos de arroz**.

# %% [markdown]
# ## 4. Preparación de los datos
# >La preparación de los datos incluye los siguientes pasos:
# >(a) Levantar las imágenes y sus etiquetas.
# >(b) Documentar las propiedades del dataset a utilizar.
# >(c) Describir sus atributos, de forma semejante a lo realizado en el pre-informe.
# > (d) Recuerde que las imágenes deben ser comparables en color, valor, rango y tamaño.

# %% [markdown]
# ### 4 (a) Levantar las imágenes y sus etiquetas

# %%
# Determina entorno de ejecución: local o Colab

# if (firstrun):
if('google.colab' in str(get_ipython() ) ):
    environment= 'google'
else:
    import os
    if (os.environ.get('PWD')=='/kaggle/working'):
        environment= 'kaggle'
    else:
        environment= 'local'
print(environment)
# Out:
# local

# %%
# Directorio base ( cambiar según el sistema de archivos de cada uno)

# if (firstrun):
if( environment== 'local' ):
    # system_path = "C:/Users/vanes/Documents/UBA/2do_cuatrimestre/DMCyT/TP/" # Vanesa
    system_path = '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/' # Víctor
elif( ( environment== 'google' ) ): 
    from google.colab import drive
    drive.mount('/content/drive')
    system_path = "/content/drive/MyDrive/maestría/cienciaTecnología/"
elif( ( environment== 'kaggle' ) )  :
    a= 1

# Diretorio del dataset
dataset_path = system_path + "tp1_dmcyt2023/datasets/Rice_Image_Dataset"

# %%
# Clases en el dataset

# Tomado de https://www.kaggle.com/code/gustavo9898/pytorch-rice-image-classification 
classes = []
for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)
    if os.path.isdir(folder_path):
        classes.append(folder)
# remove from list classes random_sample_rice_images
sample_folder_name = 'random_sample_rice_images'
if sample_folder_name in classes:
    classes.remove(sample_folder_name)
print(classes)
# Out:
# ['Basmati', 'Jasmine', 'Ipsala', 'Karacadag', 'Arborio']

# %%
# Número de imágenes por clase
for clase in classes:
  print(f"{clase}: {len(classes_path[clase])}")
# Out:
# Basmati: 15000
# Ipsala: 15000
# Arborio: 15000
# Karacadag: 15000
# Jasmine: 15000

# %%
# paths to images
classes_paths = []
for clase in classes:
  classes_paths.append(dataset_path + "/" + clase + '/')
print(classes_paths)
# Out:
# ['/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Basmati/', '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/', '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Ipsala/', '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Karacadag/', '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Arborio/']

# %%
# paths to images
images_path = classes_paths[0]
path = sorted(
  [
    os.path.join(images_path, file)
    for file in os.listdir(images_path )
    if file.endswith('.jpg')
  ]
)
print(len(path))
# Out:
# 15000

# %%
# paths to images
path = []
for class_path in classes_paths:
  path.append(
    [
      os.path.join(class_path, file)
      for file in os.listdir(class_path )
      if file.endswith('.jpg')
    ]
  )
path = sorted(path)
print(len(path))
# Out:
# 5

# %%
class_path  = classes_paths[1]
class_path
path = []
a= [
  os.path.join(class_path, file)
  for file in os.listdir(class_path )
  if file.endswith('.jpg')
]
a
# Out:
# ['/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10313).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9650).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14542).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8789).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6056).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5719).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11285).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14907).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8060).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10113).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10361).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3784).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1249).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7966).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11425).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11107).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5779).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3430).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6474).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3669).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5454).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (960).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9918).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12691).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12979).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6826).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2561).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10772).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7085).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11354).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5199).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11206).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (826).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (744).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3229).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9082).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9189).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2261).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2928).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4988).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1980).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6239).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10192).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2594).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1012).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (467).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14566).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9942).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9385).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8052).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9588).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8726).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10946).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11787).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14529).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9100).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14239).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5158).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13212).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3435).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6038).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14882).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12912).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9578).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13129).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13631).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5569).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (608).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13570).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10604).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10764).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10995).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2396).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9826).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9558).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9507).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5996).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5680).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (423).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1786).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (682).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5033).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5336).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3597).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1589).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1468).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3212).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3402).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10161).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9967).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1454).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1463).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4491).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13874).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7570).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7413).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12685).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10470).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (533).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11976).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12794).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (922).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4383).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11834).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5478).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13094).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14309).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1280).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12803).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5926).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12261).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8725).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1822).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12807).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1460).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2397).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2052).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3825).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9218).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13276).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3574).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8714).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9969).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6807).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12334).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3136).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12129).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6025).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6316).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7586).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7982).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12722).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (506).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3938).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1989).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5568).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1929).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2139).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9374).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10485).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9904).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8194).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6198).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4571).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2746).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13184).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5203).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14464).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8600).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7599).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11633).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4249).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7354).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11584).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10971).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7069).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13041).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5227).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3446).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13887).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (310).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2387).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10263).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6156).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6110).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14870).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2860).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2713).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5769).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13206).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8351).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5236).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1271).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5444).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6696).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3099).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6014).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1247).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4152).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8233).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14981).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4436).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7753).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14219).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3122).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4115).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8549).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11077).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11057).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13398).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4854).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4245).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3888).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6936).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3282).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13807).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11008).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2745).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12154).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9512).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9457).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4214).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6874).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (794).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3676).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11826).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8716).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12132).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13826).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1881).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6516).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12672).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8366).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5250).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11353).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13113).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4592).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5320).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12258).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (695).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9013).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8827).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5798).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14095).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4704).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8799).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2763).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7722).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7252).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8240).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7591).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3222).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9079).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8013).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11764).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12758).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5990).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11966).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7270).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12463).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3045).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4655).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9956).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8780).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3186).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14421).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1419).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4113).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6468).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (613).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11498).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8164).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11457).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8036).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13229).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4633).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13920).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3349).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1044).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (558).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11334).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7426).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4965).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11817).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8558).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7788).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5903).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9860).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11528).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13181).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8541).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7817).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2161).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6892).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11893).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9286).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13522).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9169).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3866).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6695).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13620).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11906).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1291).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4231).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7331).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4144).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10687).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6529).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6187).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2533).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8899).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4275).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7874).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5866).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11470).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3738).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13798).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7190).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12161).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5176).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1979).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (123).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11654).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14359).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4582).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6326).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8449).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10101).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3140).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11382).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (252).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6009).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1921).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12435).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12082).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3960).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7093).jpg',
# ...
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9880).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10978).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2106).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3660).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6678).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11549).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12134).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2576).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3817).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (144).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5362).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10224).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7251).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14983).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4628).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4785).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3797).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8133).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6790).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11839).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6447).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11154).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9452).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8531).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7600).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8504).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6022).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14946).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (981).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5917).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12250).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7611).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4134).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11626).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3777).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10847).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11885).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2857).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1240).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7784).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1576).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10512).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12381).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10767).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4032).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10955).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8385).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (659).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12552).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6671).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7086).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6199).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13525).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10435).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11843).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11373).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3056).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1699).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6604).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14593).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11722).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13480).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13368).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5452).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13567).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8297).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (13643).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4962).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9949).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3505).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11424).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (6420).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9819).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10005).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1063).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12539).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12303).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3813).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8657).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5299).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14154).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (12096).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10007).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (641).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1630).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2307).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11081).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3964).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4061).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8435).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (2274).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8386).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (5384).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9068).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (9053).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (3989).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (4363).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (14698).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (7819).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (11213).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10153).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (10411).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (737).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (8017).jpg',
#  '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Jasmine/Jasmine (1709).jpg',
#  ...]

# %%
a.append([1])
a[-1]
# Out:
# [1]

# %% [markdown]
# ## Importación de bibliotecas

# %%
# bibliotecas (libraries) incorporadas (built-in) de Python
import os
from random import randint
# Para cargar solo una vez las bibliotecas detecta si es la primer ejecución del cuaderno
try:
    os.getegid()
    firstrun = False
except:
    firstrun = True

# %%
if (firstrun):
    try:
        from tensorflow.keras.utils  import load_img
    except:
        ! pip install tensorflow
        ! pip install tensorrt
        from tensorflow.keras.utils  import load_img

from tensorflow.keras.utils  import load_img
# for loading/processing the images
# from keras.preprocessing.image import load_img
from tensorflow.keras.utils  import load_img
#from keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import img_to_array
# Out:
# 2023-09-26 08:03:08.925129: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-26 08:03:20.995687: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ¿Por qué `tensorflow.keras` y `keras`?
# [Stack overflow | keras vs. tensorflow.python.keras - which one to use?](https://stackoverflow.com/questions/48893528/keras-vs-tensorflow-python-keras-which-one-to-use)
# > tensorflow.python.keras is just a bundle of keras with a single backend inside tensorflow package. This allows you to start using keras by installing just pip install tensorflow.
# >
# > keras package contains full keras library with three supported backends: tensorflow, theano and CNTK. If you even wish to switch between backends, you should choose keras package. This approach is also more flexible because it allows to install keras updates independently from tensorflow (which may not be easy to update, for example, because the next version may require a different version of CUDA driver) or vice versa. For this reason, I prefer to install keras as another package.

# %%
if (firstrun):
    try:
        from keras.models import Model
    except:
        ! pip install keras
        from keras.models import Model

from keras.models import Model
# Tensorflow model
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import VGG16
model = VGG16()
model = Model(inputs = model.inputs, outputs = model.layers[-2].output)
# Out:
# 2023-09-26 08:03:35.009686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-26 08:03:36.222786: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# Juan: Toma la capa -2 (output), la ante-última.
# Cosas por hacer (probar)
# - Probar con otra capa intermedia (no la terminal)
#   - No es la última, más abstracta, sino tal vez una anterior

# %%
if (firstrun):
  try:
    # clustering and dimension reduction
    from sklearn.cluster import KMeans
  except:
    ! pip install scikit-learn
    from sklearn.cluster import KMeans

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
if (firstrun):
  try:
    import numpy as np
  except:
    ! pip install numpy
    import numpy as np

import numpy as np

# %%
if (firstrun):
  try:
    import matplotlib.pyplot as plt
  except:
    ! pip install matlplotlib
    import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# %% [markdown]
# ## Funciones provistas por los docentes

# %%
def preprocess(lista, model):
    datays = {}
    for i in lista:
      featuress = extract_features(i, model)
      datays[i] = featuress
    # lista de filenames
    filenmss = np.array(list(datays.keys()))

    # lista de features
    featsss = np.array(list(datays.values()))

    # reshape 4096 features por el número de imagens
    print(featsss.shape)
    featsss = featsss.reshape(-1,4096)
    return filenmss, featsss

# %%
def extract_features(file, model):
    # levanta imagen como array 224x224
    img = load_img(file, target_size=(224,224))
    # convierte img a numpy array (originalmente es 'PIL.Image.Image')
    img = np.array(img)
    # reshape para tener formato necesario para el modelo (num_of_samples, dim 1, dim 2, channels)
    reshaped_img = img.reshape(1,224,224,3)
    # prepara imagen para modelo (función de keras)
    imgx = preprocess_input(reshaped_img)
    # extrae features
    features = model.predict(imgx, use_multiprocessing=True)
    return features

# %%
# function that lets you view a cluster (based on identifier)
def view_cluster(gps,cluster):
    plt.figure(figsize = (25,25));
    # gets the list of filenames for a cluster
    files = gps
    # only allow up to 30 images to be shown at a time
    if len(files) > 10:
        print(f"Clipping cluster size from {len(files)} to 10")
        files = files[:9]
    # plot each image in the cluster
    for index, file in enumerate(files):
        plt.subplot(1,10,index+1);
        img = load_img(file)
        img = np.array(img)
        plt.imshow(img)
        plt.title('Cluster n:' + str(cluster))
        plt.axis('off')

# %% [markdown]
# ## Carga local y coalescencia en única lista

# %% [markdown]
# ### Directorio del conjuno de datos

# %%
# if (firstrun):
if('google.colab' in str(get_ipython() ) ):
    environment= 'google'
else:
    import os
    if (os.environ.get('PWD')=='/kaggle/working'):
        environment= 'kaggle'
    else:
        environment= 'local'
print(environment)
# Out:
# local

# %%
# Directorio del conjunto de datos
# Cambiar el local

# if (firstrun):
# path2 = 'datasets/Rice_Image_Dataset'
if( environment== 'local' ):
    datase_path = '/home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/'
elif( ( environment== 'google' ) ):
    from google.colab import drive
    drive.mount('/content/drive')
    dataset_path = "/content/drive/MyDrive/maestría/cienciaTecnología/datasets/tp1_dmcyt2023/Rice_Image_Dataset"
elif( ( environment== 'kaggle' ) )  :
    dataset_path = "/kaggle/input/rice-image-dataset/Rice_Image_Dataset"

# %% [markdown]
# ## Generación del archivo de etiquetas

# %%
# Tomado de https://www.kaggle.com/code/gustavo9898/pytorch-rice-image-classification
classes = []
for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)
    if os.path.isdir(folder_path):  # Check if it's a directory
        classes.append(folder)
print(classes)
# Out:
# ['Basmati', 'Ipsala', 'Arborio', 'Karacadag', 'Jasmine']

# %%
# Crear un archivo de texto para almacenar la información de todos los archivos
with open(dataset_path + '/rice_labels.txt', 'w') as dataset_file:
  # Encabezado
  dataset_file.write('file,label\n')

  # Recorrer cada directorio (clase)
  for clase in classes:
    # Obtener la ruta completa de la directorio de la clase
    directorio_clase = os.path.join(dataset_path, clase)

    # Verificar si es una directorio
    if os.path.isdir(directorio_clase):
      # Obtener la lista de archivos en la directorio de la clase
      archivos = os.listdir(directorio_clase)

      # Escribir los nombres de los archivos en el archivo de texto
      for archivo in archivos:
        # Escribir el nombre del archivo y la clase en el archivo dataset
        dataset_file.write(f'{archivo}, {clase}\n')

# %% [markdown]
# ### Carga unificada

# %%
# Arborio
image_path = DIR + path2
image_path
path = sorted(
  [
    os.path.join(image_path, file)
    for file in os.listdir(image_path )
    if file.endswith('.jpg')
  ]
)
print(len(path))
print(path[0])
# Out:
# 15000
# /home/vbettachini/documents/universitet/FCEyN/maestríaDatos/cienciaTecnología/tp1_dmcyt2023/datasets/Rice_Image_Dataset/Arborio/Arborio (1).jpg

# %%
ca = 'Karacadag (3981).jpg'
ca.split(' ')[0]
# Out:
# 'Karacadag'

# %% [markdown]
# ## Carga de imágenes desde github

# %% [markdown]
# Tener el conjunto de datos (dataset) en un repositorio en GitHub ahorra tener que cambiar el sendero (path) hacia el mismo según en que plataforma se ejecute el cuaderno (notebook).

# %%
from urllib.request import urlopen
import urllib.parse

# %%
# cargar desde github imgágenes usando load_img
# path es un URL en github
path = "https://github.com/bettachini/tp1_dmcyt2023/blob/31015882beb672c9f86d515b41f0a73fa4788078/datasets/Rice_Image_Dataset/Arborio/"
image_url = path + "Arborio (1).jpg"
encoded_url = urllib.parse.quote(image_url, safe=":/")
eins = load_img(urlopen ( encoded_url ) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       4 image_url = path + "Arborio (1).jpg"
#       5 encoded_url = urllib.parse.quote(image_url, safe=":/")
# ----> 6 eins = load_img(urlopen ( encoded_url ) )
#
# File ~/bin/jupyter/lib/python3.11/site-packages/keras/src/utils/image_utils.py:425, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
# --> 425     raise TypeError(
#     426         f"path should be path-like or io.BytesIO, not {type(path)}"
#     427     )
#     429 if color_mode == "grayscale":
#     430     # if image is not already an 8-bit, 16-bit or 32-bit grayscale image
#     431     # convert it to an 8-bit grayscale image.
#     432     if img.mode not in ("L", "I;16", "I"):
#
# TypeError: path should be path-like or io.BytesIO, not <class 'http.client.HTTPResponse'>

# %%
encoded_url
# Out:
# 'https://github.com/bettachini/tp1_dmcyt2023/blob/31015882beb672c9f86d515b41f0a73fa4788078/datasets/Rice_Image_Dataset/Arborio/Arborio%20%281%29.jpg'

# %% [markdown]
# ## Ideas

# %% [markdown]
# - Cargar los cinco paths por separado -> crear una única fuenta si es lo que necesita Keras
# - Crear archivo de labels tomando los nombres de archivo
